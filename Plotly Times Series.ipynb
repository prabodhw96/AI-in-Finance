# %%
import pandas as pd

# Using plotly.express
import plotly.express as px

# %%
df = pd.read_csv("NFLX.csv")
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-11-30  288.000000  290.809998  283.059998  286.130005  286.130005
# 1  2018-12-03  293.190002  298.720001  284.579987  290.299988  290.299988
# 2  2018-12-04  288.130005  295.739990  274.720001  275.329987  275.329987
# 3  2018-12-06  268.329987  283.220001  267.140015  282.880005  282.880005
# 4  2018-12-07  282.480011  284.209991  263.380005  265.140015  265.140015
#
#      Volume
# 0  11860100
# 1  14117400
# 2  12800600
# 3  13074300
# 4  12466700

# %%
fig = px.line(df, x=df['Date'], y=df['High'])
fig.show()
# Out:
# <div>
#
#
#             <div id="abcf957a-41da-4a53-b490-f4255f6639fa" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("abcf957a-41da-4a53-b490-f4255f6639fa")) {
#                     Plotly.newPlot(
#                         'abcf957a-41da-4a53-b490-f4255f6639fa',
# ...

# %%
# Using graph_objects
import plotly.graph_objects as go
fig = go.Figure(go.Scatter(x=df['Date'], y=df['High']))
fig.show()
# Out:
# <div>
#
#
#             <div id="073f0c33-83be-4fc2-be0a-1e2b32e2ca71" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("073f0c33-83be-4fc2-be0a-1e2b32e2ca71")) {
#                     Plotly.newPlot(
#                         '073f0c33-83be-4fc2-be0a-1e2b32e2ca71',
# ...

# %%
import datetime

fig = go.Figure(data=[go.Scatter(x=x, y=[1, 3, 6])])
# Use datetime objects to set xaxis range
fig.update_layout(xaxis_range=[datetime.datetime(2013, 10, 17), datetime.datetime(2013, 11, 20)])
fig.show()
# Out:
# <div>
#
#
#             <div id="d2825a5e-0858-4671-9a90-8c2760e60a8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d2825a5e-0858-4671-9a90-8c2760e60a8d")) {
#                     Plotly.newPlot(
#                         'd2825a5e-0858-4671-9a90-8c2760e60a8d',
#                         [{"type": "scatter", "x": ["2013-10-04T00:00:00", "2013-11-05T00:00:00", "2013-12-06T00:00:00"], "y": [1, 3, 6]}],
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df['Date'], y=df['High'], name="NFLX High", line_color='deepskyblue', opacity=0.8))
fig.add_trace(go.Scatter(x=df['Date'], y=df['Low'], name="NFLX Low", line_color='dimgray', opacity=0.8))
fig.update_layout(xaxis_range=['2019-03-01','2019-10-31'], title_text="Manually Set Date Range")
fig.show()
# Out:
# <div>
#
#
#             <div id="02beea11-2fb7-41be-885c-d190ce811623" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02beea11-2fb7-41be-885c-d190ce811623")) {
#                     Plotly.newPlot(
#                         '02beea11-2fb7-41be-885c-d190ce811623',
# ...

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=df.Date, y=df['High'], name="NFLX High", line_color='deepskyblue'))
fig.add_trace(go.Scatter(x=df.Date, y=df['Low'], name="NFLX Low", line_color='dimgray'))

fig.update_layout(title_text='Time Series with Rangeslider', xaxis_rangeslider_visible=True)

fig.show()
# Out:
# <div>
#
#
#             <div id="1e3b81d0-3c2a-4aed-a74e-f655469a69f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e3b81d0-3c2a-4aed-a74e-f655469a69f4")) {
#                     Plotly.newPlot(
#                         '1e3b81d0-3c2a-4aed-a74e-f655469a69f4',
# ...
